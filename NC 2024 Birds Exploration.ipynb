# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_table(r'C:\Users\ChaceHawkins\OneDrive - Human Coalition\Documents\Code learning\Portfolio projects\Birds\Code\ebd_Spring_2023.txt',
                   header='infer',
                   delimiter='\t',
                   low_memory=False)

# %%
df.head()
# Out:
#                           GLOBAL UNIQUE IDENTIFIER  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS1660480746
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS1663467331
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS1663466655
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS1665708081
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS1665711357
#
#              LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID  \
# 0  2023-03-20 08:05:25.592778            21168  species  avibase-69544B59
# 1  2023-03-23 21:07:03.315772            21168  species  avibase-69544B59
# 2  2023-03-23 21:08:12.437355            21168  species  avibase-69544B59
# 3  2023-03-26 12:21:15.565825            21168  species  avibase-69544B59
# 4  2023-03-26 12:21:15.565825            21168  species  avibase-69544B59
#
#      COMMON NAME        SCIENTIFIC NAME SUBSPECIES COMMON NAME  \
# 0  American Crow  Corvus brachyrhynchos                    NaN
# 1  American Crow  Corvus brachyrhynchos                    NaN
# ...

# %%
df.shape
# Out:
# (1380924, 50)

# %%
df.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE',
#        'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY',
#        'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE',
#        'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE',
#        'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE',
#        'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'SAMPLING EVENT IDENTIFIER',
#        'PROTOCOL TYPE', 'PROTOCOL CODE', 'PROJECT CODE', 'DURATION MINUTES',
#        'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS',
#        'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED',
#        'REVIEWED', 'REASON', 'TRIP COMMENTS', 'SPECIES COMMENTS',
#        'Unnamed: 49'],
# ...

# %%
df.isnull().sum()
# Out:
# GLOBAL UNIQUE IDENTIFIER            0
# LAST EDITED DATE                    0
# TAXONOMIC ORDER                     0
# CATEGORY                            0
# TAXON CONCEPT ID                    0
# COMMON NAME                         0
# SCIENTIFIC NAME                     0
# SUBSPECIES COMMON NAME        1354878
# SUBSPECIES SCIENTIFIC NAME    1354878
# EXOTIC CODE                   1330367
# OBSERVATION COUNT                   0
# BREEDING CODE                 1211588
# BREEDING CATEGORY             1211588
# BEHAVIOR CODE                 1211588
# AGE/SEX                       1375384
# COUNTRY                             0
# COUNTRY CODE                        0
# STATE                               0
# STATE CODE                          0
# COUNTY                              0
# COUNTY CODE                         0
# IBA CODE                      1181976
# BCR CODE                        39202
# USFWS CODE                    1350502
# ATLAS BLOCK                    950579
# ...

# %%
row_count = df.shape[0]
row_count
# Out:
# 1380924

# %%
df.dropna(axis=1,
          thresh=(row_count*.9),
          inplace=True,
          )

# %%
df.shape
# Out:
# (1380924, 33)

# %%
df.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'OBSERVATION COUNT', 'COUNTRY', 'COUNTRY CODE', 'STATE', 'STATE CODE',
#        'COUNTY', 'COUNTY CODE', 'BCR CODE', 'LOCALITY', 'LOCALITY ID',
#        'LOCALITY TYPE', 'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'SAMPLING EVENT IDENTIFIER',
#        'PROTOCOL TYPE', 'PROTOCOL CODE', 'PROJECT CODE', 'DURATION MINUTES',
#        'NUMBER OBSERVERS', 'ALL SPECIES REPORTED', 'HAS MEDIA', 'APPROVED',
#        'REVIEWED'],
#       dtype='object')

# %%
df.dtypes
# Out:
# GLOBAL UNIQUE IDENTIFIER      object
# LAST EDITED DATE              object
# TAXONOMIC ORDER                int64
# CATEGORY                      object
# TAXON CONCEPT ID              object
# COMMON NAME                   object
# SCIENTIFIC NAME               object
# OBSERVATION COUNT             object
# COUNTRY                       object
# COUNTRY CODE                  object
# STATE                         object
# STATE CODE                    object
# COUNTY                        object
# COUNTY CODE                   object
# BCR CODE                     float64
# LOCALITY                      object
# LOCALITY ID                   object
# LOCALITY TYPE                 object
# LATITUDE                     float64
# LONGITUDE                    float64
# OBSERVATION DATE              object
# TIME OBSERVATIONS STARTED     object
# OBSERVER ID                   object
# SAMPLING EVENT IDENTIFIER     object
# PROTOCOL TYPE                 object
# ...

# %%
pd.to_numeric(df['OBSERVATION COUNT'],errors='coerce')
# Out:
# 0          2.0
# 1          4.0
# 2          4.0
# 3          5.0
# 4          5.0
#           ...
# 1380919    1.0
# 1380920    1.0
# 1380921    1.0
# 1380922    1.0
# 1380923    1.0
# Name: OBSERVATION COUNT, Length: 1380924, dtype: float64

# %%
df['OBSERVATION COUNT'] = pd.to_numeric(df['OBSERVATION COUNT'],errors='coerce')

# %%
df['OBSERVATION COUNT'] = df['OBSERVATION COUNT'].fillna(1)

# %%
df['OBSERVATION COUNT'].isnull().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# GLOBAL UNIQUE IDENTIFIER         0
# LAST EDITED DATE                 0
# TAXONOMIC ORDER                  0
# CATEGORY                         0
# TAXON CONCEPT ID                 0
# COMMON NAME                      0
# SCIENTIFIC NAME                  0
# OBSERVATION COUNT                0
# COUNTRY                          0
# COUNTRY CODE                     0
# STATE                            0
# STATE CODE                       0
# COUNTY                           0
# COUNTY CODE                      0
# BCR CODE                     39202
# LOCALITY                         0
# LOCALITY ID                      0
# LOCALITY TYPE                    0
# LATITUDE                         0
# LONGITUDE                        0
# OBSERVATION DATE                 0
# TIME OBSERVATIONS STARTED     1462
# OBSERVER ID                      0
# SAMPLING EVENT IDENTIFIER        0
# PROTOCOL TYPE                    0
# PROTOCOL CODE                    0
# PROJECT CODE                     0
# ...

# %%
df.to_csv(r'C:\Users\ChaceHawkins\OneDrive - Human Coalition\Documents\Code learning\Portfolio projects\Birds\Spring_2023_data.csv')
